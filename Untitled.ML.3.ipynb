# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("C:\\Users\\DELL\\Downloads\\sampla data ML\\bng_property.csv")
df
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y            3        1  1000
# 1  100002000.0   197.0   LEXINGTON            N            3      1.5    --
# 2  100003000.0     NaN   LEXINGTON            N          NaN        1   850
# 3  100004000.0   201.0    BERKELEY           12            1      NaN   700
# 4          NaN   203.0    BERKELEY            Y            3        2  1600
# 5  100006000.0   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000.0     NaN  WASHINGTON          NaN            2   HURLEY   950
# 7  100008000.0   213.0     TREMONT            Y            1        1   NaN
# 8  100009000.0   215.0     TREMONT            Y           na        2  1800

# %%
df["PID"]=df["PID"].interpolate()        # 1st num 3num

# %%
df
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y            3        1  1000
# 1  100002000.0   197.0   LEXINGTON            N            3      1.5    --
# 2  100003000.0     NaN   LEXINGTON            N          NaN        1   850
# 3  100004000.0   201.0    BERKELEY           12            1      NaN   700
# 4  100005000.0   203.0    BERKELEY            Y            3        2  1600
# 5  100006000.0   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000.0     NaN  WASHINGTON          NaN            2   HURLEY   950
# 7  100008000.0   213.0     TREMONT            Y            1        1   NaN
# 8  100009000.0   215.0     TREMONT            Y           na        2  1800

# %%
df["ST_NUM"]=df["ST_NUM"].interpolate()      #

# %%
df
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y            3        1  1000
# 1  100002000.0   197.0   LEXINGTON            N            3      1.5    --
# 2  100003000.0   199.0   LEXINGTON            N          NaN        1   850
# 3  100004000.0   201.0    BERKELEY           12            1      NaN   700
# 4  100005000.0   203.0    BERKELEY            Y            3        2  1600
# 5  100006000.0   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000.0   210.0  WASHINGTON          NaN            2   HURLEY   950
# 7  100008000.0   213.0     TREMONT            Y            1        1   NaN
# 8  100009000.0   215.0     TREMONT            Y           na        2  1800

# %%
df.OWN_OCCUPIED.describe()
# Out:
# count     8
# unique    3
# top       Y
# freq      5
# Name: OWN_OCCUPIED, dtype: object

# %%
df["OWN_OCCUPIED"]=df["OWN_OCCUPIED"].fillna("Y")         # we tack Y because tis fryequency is high  ----- change NaN VALUE

# %%
df
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y            3        1  1000
# 1  100002000.0   197.0   LEXINGTON            N            3      1.5    --
# 2  100003000.0   199.0   LEXINGTON            N          NaN        1   850
# 3  100004000.0   201.0    BERKELEY           12            1      NaN   700
# 4  100005000.0   203.0    BERKELEY            Y            3        2  1600
# 5  100006000.0   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000.0   210.0  WASHINGTON            Y            2   HURLEY   950
# 7  100008000.0   213.0     TREMONT            Y            1        1   NaN
# 8  100009000.0   215.0     TREMONT            Y           na        2  1800

# %%
df["NUM_BEDROOMS"]=df["NUM_BEDROOMS"].astype(int)
df.dtypes
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 df["NUM_BEDROOMS"]=df["NUM_BEDROOMS"].astype(int)
#       2 df.dtypes
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# ...

# %%
df["NUM_BEDROOMS"]=df["NUM_BEDROOMS"].fillna(df.NUM_BEDROOMS.median())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 df["NUM_BEDROOMS"]=df["NUM_BEDROOMS"].fillna(df.NUM_BEDROOMS.median())
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:6559, in Series.median(self, axis, skipna, numeric_only, **kwargs)
#    6551 @doc(make_doc("median", ndim=1))
#    6552 def median(
#    6553     self,
#    (...)
#    6557     **kwargs,
#    6558 ):
# -> 6559     return NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:12431, in NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#   12424 def median(
#   12425     self,
#   12426     axis: Axis | None = 0,
#    (...)
#   12429     **kwargs,
#   12430 ) -> Series | float:
# > 12431     return self._stat_function(
# ...

# %%
df
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y            3        1  1000
# 1  100002000.0   197.0   LEXINGTON            N            3      1.5    --
# 2  100003000.0   199.0   LEXINGTON            N          NaN        1   850
# 3  100004000.0   201.0    BERKELEY           12            1      NaN   700
# 4  100005000.0   203.0    BERKELEY            Y            3        2  1600
# 5  100006000.0   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000.0   210.0  WASHINGTON            Y            2   HURLEY   950
# 7  100008000.0   213.0     TREMONT            Y            1        1   NaN
# 8  100009000.0   215.0     TREMONT            Y           na        2  1800

# %%
df["NUM_BATH"]=df["NUM_BATH"].astype('float')
df.dtypes
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 df["NUM_BATH"]=df["NUM_BATH"].astype('float')
#       2 df.dtypes
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# ...

# %%
df["NUM_BATH"]=df["NUM_BATH"].fillna(df.NUM_BATH.median())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 df["NUM_BATH"]=df["NUM_BATH"].fillna(df.NUM_BATH.median())
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:6559, in Series.median(self, axis, skipna, numeric_only, **kwargs)
#    6551 @doc(make_doc("median", ndim=1))
#    6552 def median(
#    6553     self,
#    (...)
#    6557     **kwargs,
#    6558 ):
# -> 6559     return NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:12431, in NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#   12424 def median(
#   12425     self,
#   12426     axis: Axis | None = 0,
#    (...)
#   12429     **kwargs,
#   12430 ) -> Series | float:
# > 12431     return self._stat_function(
#   12432         "median", nanops.nanmedian, axis, skipna, numeric_only, **kwargs
# ...

# %%
df
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y            3        1  1000
# 1  100002000.0   197.0   LEXINGTON            N            3      1.5    --
# 2  100003000.0   199.0   LEXINGTON            N          NaN        1   850
# 3  100004000.0   201.0    BERKELEY           12            1      NaN   700
# 4  100005000.0   203.0    BERKELEY            Y            3        2  1600
# 5  100006000.0   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000.0   210.0  WASHINGTON            Y            2   HURLEY   950
# 7  100008000.0   213.0     TREMONT            Y            1        1   NaN
# 8  100009000.0   215.0     TREMONT            Y           na        2  1800

# %%
df['SQ_FT']=df['SQ_FT'].fillna(df.SQ_FT.mean())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 df['SQ_FT']=df['SQ_FT'].fillna(df.SQ_FT.mean())
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:6549, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6541 @doc(make_doc("mean", ndim=1))
#    6542 def mean(
#    6543     self,
#    (...)
#    6547     **kwargs,
#    6548 ):
# -> 6549     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
#   12414     self,
#   12415     axis: Axis | None = 0,
#    (...)
#   12418     **kwargs,
#   12419 ) -> Series | float:
# > 12420     return self._stat_function(
#   12421         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12422     )
#
# ...

# %%
df
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y            3        1  1000
# 1  100002000.0   197.0   LEXINGTON            N            3      1.5    --
# 2  100003000.0   199.0   LEXINGTON            N          NaN        1   850
# 3  100004000.0   201.0    BERKELEY           12            1      NaN   700
# 4  100005000.0   203.0    BERKELEY            Y            3        2  1600
# 5  100006000.0   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000.0   210.0  WASHINGTON            Y            2   HURLEY   950
# 7  100008000.0   213.0     TREMONT            Y            1        1   NaN
# 8  100009000.0   215.0     TREMONT            Y           na        2  1800

# %%
df['PID']=df['PID'].astype(int)

# %%
df
# Out:
#          PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000   104.0      PUTNAM            Y            3        1  1000
# 1  100002000   197.0   LEXINGTON            N            3      1.5    --
# 2  100003000   199.0   LEXINGTON            N          NaN        1   850
# 3  100004000   201.0    BERKELEY           12            1      NaN   700
# 4  100005000   203.0    BERKELEY            Y            3        2  1600
# 5  100006000   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000   210.0  WASHINGTON            Y            2   HURLEY   950
# 7  100008000   213.0     TREMONT            Y            1        1   NaN
# 8  100009000   215.0     TREMONT            Y           na        2  1800

# %%
df['ST_NUM']=df['ST_NUM'].astype(int)

# %%
df
# Out:
#          PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000     104      PUTNAM            Y            3        1  1000
# 1  100002000     197   LEXINGTON            N            3      1.5    --
# 2  100003000     199   LEXINGTON            N          NaN        1   850
# 3  100004000     201    BERKELEY           12            1      NaN   700
# 4  100005000     203    BERKELEY            Y            3        2  1600
# 5  100006000     207    BERKELEY            Y          NaN        1   800
# 6  100007000     210  WASHINGTON            Y            2   HURLEY   950
# 7  100008000     213     TREMONT            Y            1        1   NaN
# 8  100009000     215     TREMONT            Y           na        2  1800
